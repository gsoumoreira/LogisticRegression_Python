# %% [markdown]
# # Logistic Regression
#
# Logistic regression is a statistical technique that aims to produce a model that allows the prediction of values taken by a categorical variable (often binary) from a series of continuous explanatory variables and / or binary. Logistic regression is widely used in medical and social sciences, and has other denominations such as logistic model, logit model, and maximum entropy classifier. (Text from [Wikipedia](https://pt.wikipedia.org/wiki/Regress%C3%A3o_log%C3%ADstica) - Portuguese)
# In this repository, we will use data from Coursera's course Machine Learning (Professor Andrew Ng from Stanford University), as well as follow the development steps of code and theory proposed by the course itself. However, python will be the programming language used, with the purpose of exercising the development of logistic regression in another language, as well as discussing other possible paths that python libraries provide.
#
# ## First Exercise
#
# These are two exercises proposed. The first **(ex1)**: Suppose that you are the administrator of a university department and you want to determine each applicant’s chance of admission based on their results on two exams. You have historical data from previous applicants that you can use as a training set for logistic regression. For each training example, you have the applicant’s scores on two exams and the admissions decision. Your task is to build a classification model that estimates an applicant’s probability of admission based the scores from those two exams.

# %% [markdown]
# ## Importing the python and created libraries

# %%
import numpy as np
import pandas as pd
import MLplot as pl # Plot Library created (Check the source code)
#%config InlineBackend.figure_formats = {'pdf',}
# %matplotlib inline

# %% [markdown]
# ##  Importing and organazing dataset
#
# Checking the dataset, there are three columns. The first column is the first exam score. The second column is the second exam score. Third collumn is the categorical binary variable (which classifies whether the student has been approved or not)

# %%
# Path do the Dataset
pathtodata = 'Exercise_Data/ex1_Data.txt'

# Importing the dataset as dataframe
data = pd.read_csv(pathtodata,delimiter = ',',header=None)

# Setting the header index for the features
data.columns = ["Exam_1","Exam_2","Result"]

# %% [markdown]
# ## Plotting classification data
#
# For The classification plot in 2D has three parameters: _**data**_ , _**colbin**_ and _**colref**_.The _**colbin**_ is the collumn with the binary classification (0 0r 1) for the  _**data**_ parameter. the _**colref**_ is refenrece collumn for plot (y axis). The data visualization is important to give the overview of the sample, helping us to make better decisions in the development to code.

# %%
#Function return fig and axe object (from matplotlib) - MLplot.
dataPlot,axes = pl.plotClassifier2D(data,2,1)
axes.set_xlabel('Exam 1',fontsize=12)
axes.set_ylabel('Exam 2',fontsize=12)
axes.legend(loc='best',frameon= True, fancybox = True)
axes.set_title('Figure 1 - Exams Score',fontsize=12);

# %% [markdown]
# ## The Sigmoid Function
#
# The sigmoid functions (also known as logistic funtion) is represented in the **Equation 1** and has the characteristc of "S"-shaped curve (**Figure 2**). The function was named by [Pierre François Verhulst](https://en.wikipedia.org/wiki/Pierre_Fran%C3%A7ois_Verhulst) in his publication: _**Loi D'Accroissement de la population**_ or **Law of Population Growth**.
#
# $$g(z) = \frac{1}{1+e^{-z}} \quad\quad (1)$$
#
# This function is interesting for binary classification. In **Figure 2** $g(z)$ **rapidaly** increase for  1  or **rapidaly** decrease for 0 when $g(z)$ is different from 0.5. Which means that , for most of $z$ values, $g(z)$ is close to one or zero.

# %%
def sigmoid(z):
    
    g = 1/(1+(np.exp(-z)))

    return g

# %%
# Plotting the sigmoid function
z = np.linspace(-25,25,1000)
sig = sigmoid(z)
sigplot = pl.plot2D(z,sig)
sigplot.set_ylabel(r'g (z)',fontsize=12)
sigplot.set_xlabel(r'z',fontsize=12)
sigplot.set_title('Figure 2 - Sigmoid function');

# %% [markdown]
# where $z =\theta^T x$ and $h_\theta(x)$ is:
#
# $$h_\theta(x)=g(z)=g(\theta^T x)\quad\quad (2)$$
#
# Important know that the choice of the hypothesis will give the boundary decision for predict the variable (y = 1 or y = 0). For instance, let's set the value of $\theta$ for a linear boundary decision as bellow:
#
# $$z = (-3)x_0 + (1)x_1 + (0)x_2 \quad\quad (3)$$
#
# Setting the conditions for **boundary decision**: if the hypothesis value is higher than zero, y = 1 and if hypothesis is lower or equal to zero, y = 0. Feel free to test different values of $\theta_0$,  $\theta_1$ and  $\theta_2$ to check different linear boundary decisions.

# %%
import ex1Boundary as bd

theta_0, theta_1, theta_2, hip   = -3, 1, 1, 0

ex1bdplot = bd.exBound(theta_0,theta_1,theta_2,hip) 
ex1bdplot.set_title("Figure 3 - Linear boundary decision for:" r'$\theta_0$={0}, $\theta_1$={1}, $\theta_2$={2}, $h_\theta(x)$={3}'.format(theta_0,theta_1,theta_2,hip));

# %% [markdown]
# ## Cost Function for Logistic Regression
#
# The cost function (J) or loss function represents the distance of its hypothesis with the real data. In linear regression, the cost function was also implemented using the equation bellow:
#
# $$J(\theta)=\frac{1}{2m}\sum_{i=1}^{m}(h_\theta(x^{(i)})-y^{(i)})^2=\frac{1}{2m}\sum_{i=1}^{m}Cost(h_\theta (x) ,y)\quad\quad (4)$$
#
# For logistic regression, the equation above is no longer the best choice for compute the cost function. Since the hypothesis for logistic regression is a non-liner function (sigmoid function), if it is computed the cost function for diferent values of theta, it will result in a _**non-convex**_ function (with many local optima). the non-convex function has high probability to **not** converge in a global minimum when gradient descent is applied. **Figure 3** shows the difference between non-convex function and convex function.
#
# <html>
# <p>
# <p>
# <body>
#     <div align="center">
#         <img src="Images/Nonconvex_func.png"
#         width = "700" /><p>
#     </div>
# </body>
# <body>
#     <div align="center">
#    Figure 4 - Non-convex function and convex function<p>
#     </div>
#     <p>
#     <p>
# </body>
# </html>
#
#
# In order to avoid the non convergence of the cost function, it is necessary adpat the previous **Equation 4** to a new one. A interesting choice is use logarithm function as shown bellow:
#
# $$
# Cost(h_\theta (x) ,y)=
#   \begin{cases}
#    -log{(h_\theta (x))} & \text{if } y=1\\
#    -log{(1-h_\theta (x))} & \text{if }y=0
#   \end{cases}
# $$
#
#
# Following the conditions above, the idea in use logarithm function is:
#
# - when the training set (y) is equal to 1 and $h_\theta (x)$ = 1, $Cost(h_\theta (x) ,y)=0$ (which is a reward)
# - when the training set (y) is equal to 1 and $h_\theta (x)$ = 0, $Cost(h_\theta (x) ,y)=\infty$ (which is a penalty)
# - when the training set (y) is equal to 0 and $h_\theta (x)$ = 0, $Cost(h_\theta (x) ,y)=0$ (which is a reward)
# - when the training set (y) is equal to 0 and $h_\theta (x)$ = 1, $Cost(h_\theta (x) ,y)=\infty$ (which is a penalty)
#
# Use these conditions, the algorithm will understand the most probably path to choose and then, converge the cost function for the global minimum. We can write the cost function in a more general form as **Equation 5**
#
# $$ J(\theta) = \frac{1}{m}\sum_{i=1}^{m}\big[-y^{(i)}\, log\,( h_\theta\,(x^{(i)}))-(1-y^{(i)})\,log\,(1-h_\theta(x^{(i)}))\big]\quad\quad (5)$$
#
# Or in a vectorized form **Equation 6**:
#
# $$ J(\theta) = \frac{1}{m}\big((\,log\,(g(X\theta))^Ty+(\,log\,(1-g(X\theta))^T(1-y)\big)\quad\quad (6)$$

# %%
def computeCost(theta,x,y):
    
    # Hypothesis function g(X*Theta)
    hip = sigmoid(x.dot(theta))
    
    # The final cost Function
    J = -1*(1/len(y))*(np.log(hip).T.dot(y)+np.log(1-hip).T.dot(1-y))
    
    return float(J)

# %% [markdown]
# ## Gradient descent for logistic regression
#
# The gradient descent in logistic regression has similar implementation compared to [linear regression](https://github.com/gsoumoreira/LinearRegression_Python) as shown in **Equation 7**. However, the hypothesis is no longer represented by a linear function. Instead, the sigmoid function is used.
#
# $$ \theta_{j} :=\theta_{j} - \frac{\alpha}{m}\sum_{i=1}^{m} ( h_\theta (x^{(i)})-y^{(i)})x^{(i)}_{j}\quad\quad (7) $$
#
# Also, as it was done in cost function, gradient descent can be vectorized **(Equation 8)**:
#
# $$ \theta_{j} := \theta_{j} -\frac{\alpha}{m} X^T(g(X\theta)-y)\quad\quad (8)$$

# %%
def gradientDescent(x, y, theta, alpha, num_iters):
    
    # Jhist variable creation
    Jhist = np.zeros([num_iters,1])
    
    # thetahist variable creation
    thetahist = np.zeros([num_iters,x.shape[1]])
    
    # Gradiante descent for iterations 
    for i in range(num_iters):

        # Compute the gradient descent(.T = transpose and .dot = matrix multiplication)
        theta =  theta - ((alpha/len(y)) * x.T.dot(sigmoid(x.dot(theta))-y))
    
        # Compute the theta history
        thetahist[i] = theta.T
    
        # Cost function History
        Jhist[i] = computeCost(theta,x,y)
    
    return [theta,Jhist,thetahist]

# %% [markdown]
# ## Important notes about update theta using gradient descent
#
# Since we are handle with logarathim and exponential equations, compute some values might give undesirable error. For instance: $log (0) = \infty$. Alpha is quite sensitve for this exercise. After many attempts, I find out that $\alpha\approx 0.001$ seems appropriate choice for converge the cost function. Moreover, it is important to note that this technique needs many iteractions, which depending of your machine, might result in a slow convergence. After one million iteractions, still, theta values did not achieve the optimum value (Even it is close from the optimum point, as shown the cost function plot - **Figure 5**). In fact, there are alternatives functions in python which is more efficient and faster, as it will be shown in the next part.

# %%
# Selecting x and y correlation features
y = data[["Result"]]
x = data[["Exam_1","Exam_2"]]

# Inserting the first column X0 with the ones
x.insert(loc=0, column='X0', value=np.ones(len(y)))

# .values = get the numpy array from DataFrame
x_val,y_val = x.values, y.values

# Initial guess for theta parameter 
theta = np.zeros([x_val.shape[1],1])

# Variables for gradient descent (alpha = learning rate) 
num_iters, alpha = 1000000, 0.001

# %%
# List witn the number of iterations
iterations = list(range(num_iters))
[besthip_G,Jhist,thetahist] = gradientDescent(x_val, y_val, theta, alpha, num_iters)
Leacur_plot = pl.plot2D(iterations,Jhist)
Leacur_plot.set_title(r'Figure 5 - Learning curve for $\alpha$={0}'.format(alpha))
Leacur_plot.set_xlabel('Iterations')
Leacur_plot.set_ylabel('Cost Function');

# %% [markdown]
# ## The *minimize()*  function
#
# Minimize function from [scipy.optimize](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html#scipy.optimize.minimize) package provides several commonly used optimization algorithms. Feel free to test different methods and dive into numerical calculus. In this exercise, it was chosen the [Truncated Newton Algorithm (TNA)](https://en.wikipedia.org/wiki/Truncated_Newton_method) (The link provides the wikipedia article). It turns out that others methods also converge quite well, and even if there is no method input, still it works well. In gradient descent, the optimum theta value after one million updates was _[-15.39, 0.12, 0.12]_, which will result in a cost function around 0.22. Using _minimize()_ the optimum theta results in _[-25,16, 0.20, 0.20]_, which will result in a cost function around 0.20. The gradient may be helpful in reduce the number of iterations used in _**minimize**_ function (**Equation 9**)
#
# $$ \frac{\delta J(\theta)}{\delta\theta_{j}} =\frac{1}{m}\sum_{i=1}^{m} ( h_\theta (x^{(i)})-y^{(i)})x^{(i)}_{j}\quad\quad (9) $$

# %%
# Partial derivative of the cost function for the minimize() argument jac
def gradient(theta, x, y):
    
    grad =(1/len(y))*x.T.dot(sigmoid(x.dot(theta.reshape(-1,1)))-y)

    # The flatten transform the grad two dimension array in one dimension array
    return grad.flatten()

# %%
# Must be array with one dimension to compute in minimize()!
initial_theta = np.zeros([x_val.shape[1]])

from scipy.optimize import minimize

# computeCostReg must return a float and the parameter to be optimizer must be
# 1D array (initial_theta ) and also must be the first arugment
# computeCostReg(theta,....)
besthip = minimize(computeCost, initial_theta, args=(x_val,y_val), method='TNC', jac=gradient)

# %% [markdown]
# ## Evaluating logistic regression
#
# After learning the parameters using _**gradientDescent()**_ and _**minimize()**_, you can use the model to predict whether a particular student will be admitted. For a student with an Exam 1 score of 45 and an Exam 2 score of 85, you should expect to see an admission probability of **68.7%** and **77.6%** respectivily. Since in _**minimize()**_ gives better convergence, it will be used for plot the boundary descision. In order to get our discrete 0 or 1 classification, we can translate the output of the hypothesis function as follows:
#
# $$
#   \begin {cases}
#    h_\theta (x) \geq 0.5 --> y=1 \quad\quad\text{Admitted}\\
#    h_\theta (x) < 0.5 --> y=0  \quad\quad\text{Not admitted}
#   \end{cases}
# $$

# %%
# Student with Exam 1 score 45 and Exam 2 score 85 - Probabity if he is addmited
# using gradient descent and minimize() function
prob0 = sigmoid(np.array([1, 45, 85]).dot(besthip_G)); # 68.7%
prob1 = sigmoid(np.array([1, 45, 85]).dot(besthip.x.T)); # 77.6%

# Setting the boundary decision equation
hip, x_b0, x_b1 = 0, 1, np.array([x.min()[2], x.max()[2]])
x_b2 = (-1/besthip.x[2])*((x_b0*besthip.x[0]) + (x_b1*besthip.x[1]) - hip)

# %%
besthip.x[0]
# Out:
# -25.16131862768876

# %%
import matplotlib.pyplot as plt

# DataPlot
dataPlot1,axes1 = pl.plotClassifier2D(data,2,1)
axes1.set_xlabel('Exam 1',fontsize=12)
axes1.set_ylabel('Exam 2',fontsize=12)
axes1.set_title('Figure 6 - Boundary Decision using optimize theta',fontsize=12)

# Sttudent with 45 and 85 score
plt.scatter(45, 85, s=60, c='r', marker='v', label='(45, 85)')

# Decision boundary plot
plt.plot(x_b1,x_b2, linewidth=2, label='Boundary')
axes1.legend(loc='best',frameon= True, fancybox = True);

# %% [markdown]
# ## Regularized logistic regression (ex2)
#
# Suppose you are the product manager of the factory and you have the test results for some microchips on two different tests. From these two tests, you would like to determine whether the microchips should be accepted or rejected. To help you make the decision, you have a dataset of test results on past microchips, from which you can build a logistic regression model.
# As shown in the overview datase plot(**Figure 7**) the decision boundary classification might not be linear for this particular case. In fact, the decision boundary looks similar a **circle** instead. To reproduce such boundary decision we should perform higher order polynomials equations. Nonetheless, higher order polynomials boundary decisions may result in **overfitting** the dataset, as we will see in this exercise.

# %% [markdown]
# ##  Importing and organazing dataset
#
# Checking the dataset2, there are three columns. The first column is the first test score. The second column is the second test score. Third collumn is the categorical binary variable (which classifies whether the microship has been approved or not)

# %%
# Path do the Dataset
pathtodata2 = 'Exercise_Data/ex2_Data.txt'

# Importing the dataset as dataframe
data2 = pd.read_csv(pathtodata2,delimiter = ',',header=None)

# Setting the header index for the features
data2.columns = ["Test1","Test2","Result"]

# %%
# Plotting classification data
dataPlot2,axes2 = pl.plotClassifier2D(data2,2,1)
axes2.set_xlabel('Microship test 1',fontsize=12)
axes2.set_ylabel('Microship test 2',fontsize=12)
axes2.legend(loc='best',frameon= True, fancybox = True)
axes2.set_title('Figure 7 - Microship test',fontsize=12);

# %% [markdown]
# ## Feature mapping
#
# In order to achieve higher order polynomials computation, we can use the [PolynomialFeatures](https://scikit-learn.org/stable/modules/generated/sklearn.preprocessing.PolynomialFeatures.html) from sklearn library to reproduce such equations. The idea of the **PolynomialFeatures** is fit the dataset with a higher order polynomial equation, creating a new dataset. For instance, let's take our dataset and apply **the Polynominal Features** for second order.

# %%
from sklearn.preprocessing import PolynomialFeatures

poly2 = PolynomialFeatures(2)

# Fitting our dataset to the new higher order polynomial dataset 
xpoly2 = poly2.fit_transform(data2[["Test1","Test2"]])
xpoly2 = pd.DataFrame(xpoly2,columns=['X0','Test1','Test2',
                                      'T1^2','T1*T2','T2^2']).head()
# Highlighting the original dataset
xpoly2.style.apply(lambda col: ['background: lightblue' if col.name == "Test1"
                                or col.name == "Test2" else '' for i in col])
# Out:
# <style  type="text/css" >
#     #T_b34980dc_1ebc_11e9_82fe_fcaa149de845row0_col1 {
#             background:  lightblue;
#         }    #T_b34980dc_1ebc_11e9_82fe_fcaa149de845row0_col2 {
#             background:  lightblue;
#         }    #T_b34980dc_1ebc_11e9_82fe_fcaa149de845row1_col1 {
#             background:  lightblue;
#         }    #T_b34980dc_1ebc_11e9_82fe_fcaa149de845row1_col2 {
#             background:  lightblue;
#         }    #T_b34980dc_1ebc_11e9_82fe_fcaa149de845row2_col1 {
#             background:  lightblue;
#         }    #T_b34980dc_1ebc_11e9_82fe_fcaa149de845row2_col2 {
#             background:  lightblue;
#         }    #T_b34980dc_1ebc_11e9_82fe_fcaa149de845row3_col1 {
#             background:  lightblue;
#         }    #T_b34980dc_1ebc_11e9_82fe_fcaa149de845row3_col2 {
#             background:  lightblue;
#         }    #T_b34980dc_1ebc_11e9_82fe_fcaa149de845row4_col1 {
#             background:  lightblue;
# ...

# %% [markdown]
# It is important to note we created new features related with **_Test1_** and **_Test2_** dataset (and also, a column with ones (X0) was added). For instance, **_T1^2_** is the square value of  **_Test1_** and so on. Also it does the combination of  **_Test1_** and  **_Test2_** which is the  represented by the feature **_T1*T2_**. At the end, we can have a higher polynomial feature in your dataset and then choose more complex boundary decisions. However, have many features might result in **_overfitting_** problem. Overfitting can be understood as a model which fits the trainning set, but does not represent the trainning set. This mean when you will try to predict using the overfitting model, it will probably return a bad prediction (**Figure 8**).
#
# <html>
# <p>
# <p>
# <body>
#     <div align="center">
#         <img src="Images/Under_Overfitting.PNG"
#         width = "700" /><p>
#     </div>
# </body>
# <body>
#     <div align="center">
#    Figure 8 - Underfitting (left) good fitting (center) and overfitting (right) of some trainning dataset<p>
#     </div>
#     <p>
#     <p>
# </body>
# </html>

# %% [markdown]
# ## Regularized cost function and gradient
#
# Once we want many features and complex boundaries decisions, we will probably face overfitting problem. In order to solve it, we can implement the _**Regularized Term**_ for our cost function and gradient descent algorithm. The regularized cost functions in represented in **Equation 10**.
#
# $$ J(\theta) = \frac{1}{m}\sum_{i=1}^{m}\big[-y^{(i)}\, log\,( h_\theta\,(x^{(i)}))-(1-y^{(i)})\,log\,(1-h_\theta(x^{(i)}))\big] + \frac{\lambda}{2m}\sum_{j=1}^{n}\theta_{j}^{2}\quad\quad (10) $$
#
# and the gradient is the **Equation 11** below:
#
# $$ \frac{\delta J(\theta)}{\delta\theta_{j}} = \frac{1}{m}\sum_{i,j=1}^{m,n} ( h_\theta (x^{(i)})-y^{(i)})x^{(i)}_{j} + \frac{\lambda}{m}\theta_{j}\quad\quad (11)$$
#
# $$ \frac{\delta J(\theta)}{\delta\theta_{j}} = \frac{1}{m}\sum_{i=1}^{m} ( h_\theta (x^{(i)})-y^{(i)})x^{(i)}_{j}\quad\quad\text{for j = 0}$$
#
# Where $\lambda$ is the **Regularized Parameter**. The main idea in use regularization is to reduce the influence of some features in the hypothesis. We will try to show in this exercise the influence of the regularization by plotting the boundaries decisions. (**Note: The X0 or the "ones" column is not regularized**)

# %%
def computeCostReg(theta, reg, x, y):

    # Hypothesis function g(X*Theta)
    hip = sigmoid(x.dot(theta))
    
    # The regularized cost Function (Changing the thenta_0 to 0)
    J = -1*(1/len(y))*(np.log(hip).T.dot(y)+np.log(1-hip).T.dot(1-y))
    + (reg/(2*len(y)))*np.sum(np.square(theta[1:]))
    
    return float (J)

# %%
def gradientReg(theta, reg, x, y):

    # Hypothesis function g(X*Theta)
    hip = sigmoid(x.dot(theta.reshape(-1,1) ))
    
    # The Regularized gradient (Changing the thenta_0 to 0 temporaly)
    theta_0 = theta[0]
    theta[0] = 0
    grad = (1/len(y))*x.T.dot(hip-y) + (reg/len(y))*theta.reshape(-1,1) 
    theta[0] = theta_0
    
    return grad.flatten()

# %% [markdown]
# For this exercise, let's fit out dataset in a 6-order polynomial features and then calculate the cost function regularized:

# %%
poly6 = PolynomialFeatures(6)

# Fitting our dataset to the new higher order polynomial dataset 
xpoly6 = poly6.fit_transform(data2[["Test1","Test2"]])

# Binary (y) classification dataset
y6 = data2[["Result"]].values

# Theta should be same size of xpoly6!
theta6 = np.zeros([xpoly6.shape[1]])

# Regularized Parameter
reg = 1

# Compute regulizared cost function
computeCostReg(theta6, reg, xpoly6, y6)
# Out:
# 0.6931471805599453

# %% [markdown]
# ## Evaluating regularized logistic regression
#
# For hypothesis parameters optimization we will use again the _**minimize()**_ function from [scipy.optimize](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.minimize.html#scipy.optimize.minimize) package. To see the regularization performance, let's plot the boundaries decisions for different regularized parameters. The _**contour**_ plot seems more appropriate for boundary decision vizualization (since we now have many features, write the equations does not look a good idea). The _**contour**_ is a 3D plot represented in 2D. In this case, we will set the _**z**_ coordinate as different values of hypothesis. In other words, it is possible to vizualize different boundaries decisions changing the value of the hypothesis. As it was discussed previously, when _**g(z) =0.5**_ (hypothesis = 0.5) it means the center of the sigmoid function, therefore it was choosen for plotting. Also, it was computed three boundary decisions for different regularized parameters (0, 1 and 100). It turns out that the boundary decision that represents better the dataset is when _**reg = 1**_. When we have _**reg= 0**_ we have better accuracy, however it is clear that the shape of the boundary line does not fit as expected (The overfitting probelm). And finally, when _**reg= 100**_ we have the underfitting.

# %%
# Regularized Parameter list
reg = [0,1,100]

# Optimized parameters for respective regularized parameters
besthip0 = minimize(computeCostReg, theta6, args=(reg[0],xpoly6,y6), method='TNC', jac=gradientReg)
besthip1 = minimize(computeCostReg, theta6, args=(reg[1],xpoly6,y6), method='TNC', jac=gradientReg)
besthip100 = minimize(computeCostReg, theta6, args=(reg[2],xpoly6,y6), method='TNC', jac=gradientReg)

best = [besthip0.x,besthip1.x,besthip100.x]

# Regularized Parameter choice
best_choice = best[1]

# Creating date test point for the boundary decision plot
x1_minmax = np.linspace(data2["Test1"].min(), data2["Test1"].max(),50)
x2_minmax = np.linspace(data2["Test2"].min(), data2["Test2"].max(),50)

# Accuracy for regulized parameter choice
predict = sigmoid(xpoly6.dot(best_choice.reshape(-1,1))) >= 0.5
accuracy = float(100*sum(predict == y6)/len(y6)) 

# Creatting a meshgrid with the data test (matrix (n,n) with the data
u,v = np.meshgrid(x1_minmax,x2_minmax)

# Hypothesis computation using data test (np.c_ -> add a new column)
h = sigmoid(poly6.fit_transform(np.c_[u.flatten(), v.flatten()]).dot(best_choice))

# Reshaping the z data for two dimensional matrix u or v
z = h.reshape(u.shape)

# Plotting the original data
Regplot, ax = pl.plotClassifier2D(data2,2,1)

# Plotting the contour plot (g(z)=0.5)
plt.contour(u, v, z, [0.5],linewidths=2, colors='lightgreen')

ax.set_xlabel('Microship test 1',fontsize=12)
ax.set_ylabel('Microship test 2',fontsize=12)
ax.set_title(r'Figure 9 - Boundary Decision with Accuracy {}% and with $\Lambda$ = {}'
             .format(np.round(accuracy, decimals=2),reg[1]),fontsize=12)
ax.legend(loc='best',frameon= True, fancybox = True);
